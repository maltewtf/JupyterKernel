# %%
%help
# Out:
# Currently the following commands are available:
#   %help                     -- list available magics and their function.
#   %print                    -- print the current program including imports, functions and statements.
#   %flags                    -- print flags that are used when running sac2c.
#   %setflags <flags>         -- set sac2c falgs to <flags>.

# %%
x = 1;
if (x < 0) print(x);

# %%
x = 4;
y = [91, 85, 76];
z = "abc";

# %%
int test(int x) {
    return x + 1;
}

# %%
int test(int x) {
    return x + 100;
}

# %%
test(10)
# Out:
# Dimension:  0
# Shape    : < >
#  110

# %%
%print
# Out:
# // use
# use Jupyter: all;
# use StdIO: all;
# use Array: all;
#
# // imports
#
#
# // typedefs
#
#
# // functions
# int test(int x) {
#     return x + 100;
# }
#
# int main() {
#     // definitions
#     x = 4 ;
#     y = [91 , 85 , 76 ];
#     z = "abc";
#
#     // statements
#
#
#     // expression
#
#
#     // assignments
#     printf("--- internal variables ---");
#
#     return 0;
# }

# %%
print(x);
# Out:
# Dimension:  0
# Shape    : < >
#  4

# %%
y = 10;
print(y);
# Out:
# Dimension:  0
# Shape    : < >
#  10

# %%
y
# Out:
# Dimension:  0
# Shape    : < >
#  10

# %%
x = x + 10;

# %%
x
# Out:
# Dimension:  0
# Shape    : < >
#  14
